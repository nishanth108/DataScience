# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
dataset=pd.read_csv('dataset/studentclusters.csv')

# %%
dataset
# Out:
# Running cells with 'Python 3.11.5' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/nisha/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
X=dataset.copy()
X.plot.scatter(x='marks',y='shours')
# Out:
# <Axes: xlabel='marks', ylabel='shours'>

# %%
from sklearn.preprocessing import minmax_scale
X_original=X
X=minmax_scale(X)

# %%
from sklearn.cluster import KMeans
inertia=[]
for i in range(1,15):
  model=KMeans(n_clusters=i)
  model.fit(X)
  inertia.append(model.inertia_)
plt.plot(range(1,15),inertia,marker='o')
plt.show()
# Out:
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
model=KMeans(n_clusters=5)
clusters=model.fit_predict(X)
# Out:
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
inertia=model.inertia_
labels=model.labels_
print(inertia)
print(labels)
# Out:
# 0.5752619558845886
# [2 0 4 2 3 0 4 3 2 4 2 4 0 2 3 0 0 3 0 2 3 4 0 0 0 1 0 0 3 0 1 1 4 1 0 1 0
#  0 0 4 1 0 2 0 2 0 0 1 2]

# %%
X=X_original

# %%
X
# Out:
#     marks  shours
# 0      72    20.0
# 1      42    19.0
# 2      77     7.0
# 3      93    22.0
# 4      30    20.0
# 5      53    15.0
# 6      74     8.0
# 7      28    24.0
# 8      69    26.0
# 9      64     7.0
# 10     87    30.0
# 11     70     8.0
# 12     42    18.0
# 13     79    23.0
# 14     37    22.0
# 15     52    16.0
# 16     51    15.0
# 17     25    23.0
# 18     48    17.0
# 19     85    21.0
# 20     22    21.0
# 21     63     7.5
# 22     42    17.0
# 23     60    15.0
# 24     56    18.0
# 25     23     5.0
# 26     42    16.0
# 27     40    14.0
# 28     28    27.0
# 29     47    17.0
# 30     25     3.0
# 31     31     4.0
# 32     63     9.0
# 33     34     2.0
# 34     49    14.0
# 35     23     2.0
# 36     56    16.0
# 37     45    14.0
# 38     53    16.0
# 39     73    10.0
# 40     22     4.0
# 41     52    18.0
# 42     64    23.0
# 43     42    16.0
# 44     82    26.0
# 45     40    17.0
# 46     40    16.0
# 47     20     5.0
# 48     81    21.0

# %%
labels=pd.DataFrame(labels)
df=pd.concat([X,labels],axis=1)
df=df.rename(columns={0:'label'})

# %%
df
# Out:
#     marks  shours  label
# 0      72    20.0      2
# 1      42    19.0      0
# 2      77     7.0      4
# 3      93    22.0      2
# 4      30    20.0      3
# 5      53    15.0      0
# 6      74     8.0      4
# 7      28    24.0      3
# 8      69    26.0      2
# 9      64     7.0      4
# 10     87    30.0      2
# 11     70     8.0      4
# 12     42    18.0      0
# 13     79    23.0      2
# 14     37    22.0      3
# 15     52    16.0      0
# 16     51    15.0      0
# 17     25    23.0      3
# 18     48    17.0      0
# 19     85    21.0      2
# 20     22    21.0      3
# 21     63     7.5      4
# 22     42    17.0      0
# 23     60    15.0      0
# 24     56    18.0      0
# 25     23     5.0      1
# 26     42    16.0      0
# 27     40    14.0      0
# 28     28    27.0      3
# 29     47    17.0      0
# 30     25     3.0      1
# 31     31     4.0      1
# 32     63     9.0      4
# 33     34     2.0      1
# 34     49    14.0      0
# 35     23     2.0      1
# 36     56    16.0      0
# 37     45    14.0      0
# 38     53    16.0      0
# 39     73    10.0      4
# 40     22     4.0      1
# 41     52    18.0      0
# 42     64    23.0      2
# 43     42    16.0      0
# 44     82    26.0      2
# 45     40    17.0      0
# 46     40    16.0      0
# 47     20     5.0      1
# 48     81    21.0      2

# %%
df.plot.scatter(x='marks',y='shours',c='label',colormap='Set1');
